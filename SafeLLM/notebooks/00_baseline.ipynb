# %%
from safellm.runner.inspect_task_runner import run_yaml
from inspect_ai import eval

task = run_yaml("scenarios/global_benign.yaml", trace_path="data/runs/raw/runs_dev.jsonl")
results = eval(task, model="hf/Qwen/Qwen2.5-1.5B-Instruct")
results
